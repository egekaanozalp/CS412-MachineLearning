# %% [markdown]
# # Preparation Step

# %% [markdown]
# In this step, the data is analyzed and visualized by using DataFrame objects of Pandas library.

# %%
import pandas as pd

# %%
conversion_df = pd.read_csv("conversionRates.csv")
conversion_df
# Out:
#     Unnamed: 0 originCountry  exchangeRate
# 0            1           USD      1.000000
# 1            2           EUR      1.195826
# 2            3           INR      0.015620
# 3            4           GBP      1.324188
# 4            5           BRL      0.321350
# ..         ...           ...           ...
# 81          82           SVC      0.114124
# 82          83           SZL      0.077002
# 83          84           UYU      0.034642
# 84          85           XAF      0.001823
# 85          86           YER      0.003996
#
# [86 rows x 3 columns]

# %%
freeform_df = pd.read_csv("freeformResponses.csv")
conversion_df
# Out:
# <ipython-input-3-bdcfc53c455d>:1: DtypeWarning: Columns (5,17,21,38,50) have mixed types. Specify dtype option on import or set low_memory=False.
#   freeform_df = pd.read_csv("freeformResponses.csv")
#     Unnamed: 0 originCountry  exchangeRate
# 0            1           USD      1.000000
# 1            2           EUR      1.195826
# 2            3           INR      0.015620
# 3            4           GBP      1.324188
# 4            5           BRL      0.321350
# ..         ...           ...           ...
# 81          82           SVC      0.114124
# 82          83           SZL      0.077002
# 83          84           UYU      0.034642
# 84          85           XAF      0.001823
# 85          86           YER      0.003996
#
# [86 rows x 3 columns]

# %%
multipleChoice_df = pd.read_csv("multipleChoiceResponses.csv",
                                encoding='latin-1')
multipleChoice_df
# Out:
# <ipython-input-4-0eaac30224ae>:1: DtypeWarning: Columns (31,83,86,87,98,99,109,116,123,124,127,129,130,164) have mixed types. Specify dtype option on import or set low_memory=False.
#   multipleChoice_df = pd.read_csv("multipleChoiceResponses.csv",
#                                             GenderSelect        Country   Age  \
# 0      Non-binary, genderqueer, or gender non-conforming            NaN   NaN
# 1                                                 Female  United States  30.0
# 2                                                   Male         Canada  28.0
# 3                                                   Male  United States  56.0
# 4                                                   Male         Taiwan  38.0
# ...                                                  ...            ...   ...
# 16711                                             Female          Other  24.0
# 16712                                               Male      Indonesia  25.0
# ...

# %%
schema_df = pd.read_csv("schema.csv")
schema_df
# Out:
#                              Column  \
# 0                      GenderSelect
# 1                    GenderFreeForm
# 2                           Country
# 3                               Age
# 4                  EmploymentStatus
# ..                              ...
# 285                 JobFactorRemote
# 286               JobFactorIndustry
# 287       JobFactorLeaderReputation
# 288              JobFactorDiversity
# 289  JobFactorPublishingOpportunity
#
#                                               Question     Asked
# 0       Select your gender identity. - Selected Choice       All
# 1    Select your gender identity. - A different ide...       All
# 2            Select the country you currently live in.       All
# 3                                     What's your age?       All
# 4               What's your current employment status?       All
# ..                                                 ...       ...
# 285  How are you assessing potential job opportunit...  Learners
# ...

# %% [markdown]
# # The Context of the Analysis

# %% [markdown]
# In the following questions, while analyzing probabilities, the missing values of the datasets are ignored to avoid miscalculation. E.g.: Suppose that we are looking for the probability of people who are older than 30 and living in France. In this case, to avoid miscalculation (underestimation), I ignored the cases such as (nAn, France) or (35, nAn) since they increase the value of denominator while keeping the value of the numerator the same.
#
# This issue can be handled by filling these values using the mean value or using kNN algorithm (or any other machine learning algorithms). However, such options are out of scope of this homework. Hence, these data points are ignored in the following calculations.

# %% [markdown]
# # Question 1

# %% [markdown]
# Question: What is the probability that a respondent is currently employed as a Programmer given they use C/C++ at work?
#
# Mathematical Notation of the Question: P(Y='Programmer' | X='C/C++')

# %%
# This cell focuses on X='C/C++':
c_cpp_df = multipleChoice_df[(multipleChoice_df["WorkToolsSelect"].
                             str.contains("C/C++", na=False, regex=False)) &
                              (multipleChoice_df["CurrentJobTitleSelect"].isnull()
                              ==False)][["CurrentJobTitleSelect", "WorkToolsSelect"]]
c_cpp_df
# Out:
#        CurrentJobTitleSelect  \
# 4         Computer Scientist
# 6         Computer Scientist
# 15     DBA/Database Engineer
# 21                Researcher
# 23                     Other
# ...                      ...
# 16634       Business Analyst
# 16660   Scientist/Researcher
# 16677             Programmer
# 16694         Data Scientist
# 16706                  Other
#
#                                          WorkToolsSelect
# 4      C/C++,Jupyter notebooks,MATLAB/Octave,Python,R...
# 6      C/C++,Cloudera,Hadoop/Hive/Pig,Java,NoSQL,R,Un...
# 15     C/C++,IBM Cognos,MATLAB/Octave,Microsoft Excel...
# 21             C/C++,Jupyter notebooks,Python,TensorFlow
# 23     C/C++,Java,Jupyter notebooks,MATLAB/Octave,Pyt...
# ...                                                  ...
# 16634  C/C++,Hadoop/Hive/Pig,Java,Microsoft Azure Mac...
# 16660  C/C++,Jupyter notebooks,MATLAB/Octave,Python,T...
# 16677  C/C++,Python,Spark / MLlib,TensorFlow,Unix she...
# ...

# %%
# This cell focuses on Y='Programmer' | X='C/C++':
prog_df = c_cpp_df[c_cpp_df["CurrentJobTitleSelect"]=="Programmer"]
prog_df
# Out:
#       CurrentJobTitleSelect                                    WorkToolsSelect
# 1429             Programmer  Amazon Web services,C/C++,Java,SQL,Tableau,Uni...
# 1484             Programmer  Amazon Web services,C/C++,Java,MATLAB/Octave,N...
# 1869             Programmer                                     C/C++,Python,R
# 1991             Programmer  C/C++,Java,NoSQL,Python,SQL,Tableau,Unix shell...
# 2872             Programmer                              C/C++,Java,Python,SQL
# 3194             Programmer                                 C/C++,NoSQL,Python
# 3755             Programmer  C/C++,Java,Jupyter notebooks,Python,SQL,Tensor...
# 3788             Programmer  Amazon Web services,C/C++,Cloudera,Google Clou...
# 3822             Programmer  C/C++,Jupyter notebooks,Microsoft Azure Machin...
# 4298             Programmer                                     C/C++,Python,R
# 4598             Programmer  C/C++,Java,MATLAB/Octave,Microsoft Excel Data ...
# ...

# %%
# This cell focuses on P(Y='Programmer' | X='C/C++'):
print("P(Y='Programmer' | X='C/C++') =", len(prog_df)/len(c_cpp_df))
# Out:
# P(Y='Programmer' | X='C/C++') = 0.02226588081204977

# %% [markdown]
# # Question 2

# %% [markdown]
# Question: What is the probability that a respondent is a Data Scientist given they have majored in computer science, mathematics or statistics?
#
# Mathematical Notation of the Question: P(Y='Data Scientist' | X={'Computer Scientist', 'Mathematics or statistics'})

# %%
# This cell focuses on X={'Computer Scientist', 'Mathematics or statistics'}:
cs_math_stat_df = multipleChoice_df[(multipleChoice_df["MajorSelect"] ==
                                    "Computer Science") | (multipleChoice_df
                                     ["MajorSelect"] == "Mathematics or statistics")]
cs_math_stat_df = cs_math_stat_df[cs_math_stat_df["CurrentJobTitleSelect"].isnull()==False]
cs_math_stat_df = cs_math_stat_df[["CurrentJobTitleSelect", "MajorSelect"]]
cs_math_stat_df
# Out:
#                       CurrentJobTitleSelect                MajorSelect
# 3          Operations Research Practitioner  Mathematics or statistics
# 7      Software Developer/Software Engineer           Computer Science
# 12                                 Engineer  Mathematics or statistics
# 14     Software Developer/Software Engineer           Computer Science
# 15                    DBA/Database Engineer  Mathematics or statistics
# ...                                     ...                        ...
# 16693                          Data Analyst  Mathematics or statistics
# 16695                      Business Analyst           Computer Science
# 16697                                 Other  Mathematics or statistics
# 16703                          Data Analyst  Mathematics or statistics
# 16712                            Programmer           Computer Science
#
# [5025 rows x 2 columns]

# %%
# This cell focuses on Y = 'Data Scientist' | X={'Computer Scientist',
# 'Mathematics or statistics'}:
ds_df = cs_math_stat_df[cs_math_stat_df["CurrentJobTitleSelect"]=="Data Scientist"]
ds_df
# Out:
#       CurrentJobTitleSelect                MajorSelect
# 27           Data Scientist           Computer Science
# 41           Data Scientist  Mathematics or statistics
# 65           Data Scientist           Computer Science
# 67           Data Scientist  Mathematics or statistics
# 72           Data Scientist           Computer Science
# ...                     ...                        ...
# 16605        Data Scientist  Mathematics or statistics
# 16615        Data Scientist  Mathematics or statistics
# 16641        Data Scientist  Mathematics or statistics
# 16666        Data Scientist  Mathematics or statistics
# 16678        Data Scientist  Mathematics or statistics
#
# [1057 rows x 2 columns]

# %%
# This cell focuses on P(Y='Data Scientist' | X={'Computer Scientist',
# 'Mathematics or statistics'}):
print("P(Y='Data Scientist' | X={'Computer Scientist', 'Mathematics or statistics'}) =",
      len(ds_df) / len(cs_math_stat_df))
# Out:
# P(Y='Data Scientist' | X={'Computer Scientist', 'Mathematics or statistics'}) = 0.21034825870646767

# %% [markdown]
# # Question 3

# %% [markdown]
# Question: What is the probability that a respondent works in the Technology industry given that they earn more than 40,000 USD annually?
#
# Mathematical Notation of the Question: P(Y="Technology" | X ∈ (40000, ∞) USD)
#
# Note: See that the value of 40,000 USD is not included since we are focusing on values more than 40,000 USD.

# %%
# This function is created to convert the compensation amount values of the data
# points to USD. It is used with pd.apply function:
def convert_salary(row, exchange_rate_df):
    currency = row["CompensationCurrency"]
    exchange_rate_series = exchange_rate_df[exchange_rate_df["originCountry"] ==
                                            currency]["exchangeRate"]
    if not exchange_rate_series.empty:
        exchange_rate = float(exchange_rate_series.iloc[0])
        salary_usd = float(row["CompensationAmount"]) * exchange_rate
        row["CompensationAmount"] = salary_usd
        row["CompensationCurrency"] = "USD"
    else:
      print("Currency", currency, "is not in the list!")
    return row

# %%
# This cell focuses on X ∈ (40000, ∞) USD:
salary_df = multipleChoice_df[(multipleChoice_df["CompensationAmount"].isnull()==
                               False) & (multipleChoice_df["CompensationCurrency"].
                                         isnull()==False) & (multipleChoice_df
                                          ["EmployerIndustry"].isnull()==False)][
                                              ["EmployerIndustry",
                                               "CompensationAmount",
                                               "CompensationCurrency"]]

salary_df["CompensationAmount"] = pd.to_numeric(salary_df["CompensationAmount"],
                                                errors="coerce")

salary_df = salary_df.apply(lambda row: convert_salary(row, conversion_df), axis=1)
salary_df = salary_df[(salary_df["CompensationCurrency"] == "USD")]
salary_df = salary_df[salary_df["CompensationAmount"] > 40000]
salary_df = salary_df[salary_df["EmployerIndustry"].isnull()==False]
salary_df
# Out:
# Currency SPL is not in the list!
#          EmployerIndustry  CompensationAmount CompensationCurrency
# 8              Non-profit           64184.800                  USD
# 22     Telecommunications          100000.000                  USD
# 27              Financial           53352.000                  USD
# 28         Internet-based          179373.900                  USD
# 34             Technology          133000.000                  USD
# ...                   ...                 ...                  ...
# 16502          Government           65770.430                  USD
# 16507               Other           50000.000                  USD
# 16517  Telecommunications          100449.384                  USD
# 16525          Technology          200000.000                  USD
# 16577           Financial           89686.950                  USD
#
# [2225 rows x 3 columns]

# %%
# This cell focuses on Y="Technology" | X ∈ (40000, ∞) USD:
tech_df = salary_df[salary_df["EmployerIndustry"] == "Technology"]
tech_df
# Out:
#       EmployerIndustry  CompensationAmount CompensationCurrency
# 34          Technology           133000.00                  USD
# 37          Technology            80000.00                  USD
# 75          Technology           215000.00                  USD
# 158         Technology            59588.46                  USD
# 277         Technology            64148.00                  USD
# ...                ...                 ...                  ...
# 15171       Technology            93720.00                  USD
# 15499       Technology            59947.20                  USD
# 15517       Technology            66209.40                  USD
# 16281       Technology           107624.34                  USD
# 16525       Technology           200000.00                  USD
#
# [437 rows x 3 columns]

# %%
# This cell focuses on P(Y="Technology" | X ∈ (40000, ∞) USD):
print("P(Y='Technology' | X ∈ (40000, ∞) USD) =", len(tech_df)/len(salary_df))
# Out:
# P(Y='Technology' | X ∈ (40000, ∞) USD) = 0.19640449438202248

# %% [markdown]
# # Question 4

# %% [markdown]
# Question: What is the joint probability of a respondent being over 30 years old and having at least a Bachelor’s degree?
#
# Mathematical Notation of the Question: P(X_1 ∩ X_2) where X_1 is "respondent being over 30 years old" and X_2 is "respondent having at least a Bachelor’s degree".

# %%
# See that the degrees that have more or equal importance to Bachelor's Degree
# form the set: {"Bachelor's degree", "Master's degree", "Doctoral degree",
# 'Professional degree'}
multipleChoice_df["FormalEducation"].unique()
# Out:
# array(["Bachelor's degree", "Master's degree", 'Doctoral degree', nan,
#        "Some college/university study without earning a bachelor's degree",
#        'I did not complete any formal education past high school',
#        'Professional degree', 'I prefer not to answer'], dtype=object)

# %%
# This cell focuses on X_1 ∩ X_2 which is respondents that are over 30 years old
# and possess at least a Bachelor’s degree:
objective_degrees = ["Bachelor's degree", "Master's degree", "Doctoral degree",
                     "Professional degree"]
age_degree_df = multipleChoice_df[multipleChoice_df["FormalEducation"].
                                  isin(objective_degrees)][["FormalEducation",
                                                            "Age"]]
age_degree_df = age_degree_df[(age_degree_df["Age"]>30)]
age_degree_df
# Out:
#          FormalEducation   Age
# 3        Master's degree  56.0
# 4        Doctoral degree  38.0
# 5        Doctoral degree  46.0
# 6        Master's degree  35.0
# 8      Bachelor's degree  43.0
# ...                  ...   ...
# 16692  Bachelor's degree  34.0
# 16697    Master's degree  32.0
# 16700    Master's degree  45.0
# 16701  Bachelor's degree  33.0
# 16709    Master's degree  34.0
#
# [6467 rows x 2 columns]

# %%
# This cell focuses on the denominator of the probability function which is the
# number of data points which does not have missing value on columns 'Age' and
# 'FormalEducation':
denominator_df = multipleChoice_df[(multipleChoice_df["FormalEducation"].isnull()
                                   ==False) & (multipleChoice_df["Age"].isnull()
                                   ==False)]
denominator_df[["FormalEducation", "Age"]]
# Out:
#                                          FormalEducation   Age
# 1                                        Master's degree  30.0
# 2                                        Master's degree  28.0
# 3                                        Master's degree  56.0
# 4                                        Doctoral degree  38.0
# 5                                        Doctoral degree  46.0
# ...                                                  ...   ...
# 16710                                  Bachelor's degree  23.0
# 16711                                    Master's degree  24.0
# 16712                                  Bachelor's degree  25.0
# 16714                             I prefer not to answer  16.0
# 16715  I did not complete any formal education past h...  27.0
#
# [14782 rows x 2 columns]

# %%
# This cell focuses on P(X_1 ∩ X_2):
print("P(X_1 ∩ X_2) =", len(age_degree_df)/len(denominator_df))
# Out:
# P(X_1 ∩ X_2) = 0.4374915437694493

# %% [markdown]
# # Question 5

# %% [markdown]
# Question: What is the probability that a respondent is a Data Scientist who majored in Computer Science, Mathematics or statistics?
#
# Mathematical Notation of the Question : P(X_1 ∩ X_2) where X_1 is "respondent is a Data Scientist" and X_2 is "respondent majored in 'Computer Science' or 'Mathematics or statistics'".

# %%
# This cell focuses on X_1 ∩ X_2 = respondent is a Data Scientist who majored in
# 'Computer Science' or 'Mathematics or statistics':
cs_math_stat_df = multipleChoice_df[(multipleChoice_df["MajorSelect"] ==
                                    "Computer Science") | (multipleChoice_df
                                     ["MajorSelect"] == "Mathematics or statistics")]
cs_math_stat_df = cs_math_stat_df[cs_math_stat_df["CurrentJobTitleSelect"]==
                                  "Data Scientist"]
cs_math_stat_df = cs_math_stat_df[["CurrentJobTitleSelect", "MajorSelect"]]
cs_math_stat_df
# Out:
#       CurrentJobTitleSelect                MajorSelect
# 27           Data Scientist           Computer Science
# 41           Data Scientist  Mathematics or statistics
# 65           Data Scientist           Computer Science
# 67           Data Scientist  Mathematics or statistics
# 72           Data Scientist           Computer Science
# ...                     ...                        ...
# 16605        Data Scientist  Mathematics or statistics
# 16615        Data Scientist  Mathematics or statistics
# 16641        Data Scientist  Mathematics or statistics
# 16666        Data Scientist  Mathematics or statistics
# 16678        Data Scientist  Mathematics or statistics
#
# [1057 rows x 2 columns]

# %%
# This cell focuses on the denominator of the probability function which is the
# number of data points which does not have missing value on columns
# 'CurrentJobTitleSelect' and 'MajorSelect':
denominator_df = multipleChoice_df[(multipleChoice_df["CurrentJobTitleSelect"].isnull()
                                   ==False) & (multipleChoice_df["MajorSelect"].isnull()
                                   ==False)]
denominator_df[["CurrentJobTitleSelect", "MajorSelect"]]
# Out:
#                   CurrentJobTitleSelect                         MajorSelect
# 0                 DBA/Database Engineer      Management information systems
# 3      Operations Research Practitioner           Mathematics or statistics
# 4                    Computer Scientist  Engineering (non-computer focused)
# 5                        Data Scientist              Electrical Engineering
# 6                    Computer Scientist              Electrical Engineering
# ...                                 ...                                 ...
# 16702                      Data Analyst                               Other
# 16703                      Data Analyst           Mathematics or statistics
# 16706                             Other              Electrical Engineering
# 16709             DBA/Database Engineer              Electrical Engineering
# 16712                        Programmer                    Computer Science
#
# [10419 rows x 2 columns]

# %%
# This cell focuses on P(X_1 ∩ X_2):
print("P(X_1 ∩ X_2) =", len(cs_math_stat_df)/len(denominator_df))
# Out:
# P(X_1 ∩ X_2) = 0.10144927536231885

# %% [markdown]
# # Question 6

# %% [markdown]
# Question: What is the joint probability that a respondent is from France, earns less than 100,000 USD annually, and uses Cross-Validation Often or Most of the time?
#
# Question Notation: P(X_1 ∩ X_2 ∩ X_3) where X_1 is "respondent is from France", X_2 is "respondent earns less than 100,000 USD annually" and X_3 is "respondent uses Cross-Validation Often or Most of the time".

# %%
# This cell focuses on X_1 ∩ X_2 ∩ X_3:
# Start with filtering X_2:
salary_df = multipleChoice_df[(multipleChoice_df["Country"].isnull()==False) &
                              (multipleChoice_df["CompensationAmount"].isnull()==False) &
                              (multipleChoice_df["CompensationCurrency"].isnull()==False) &
                              (multipleChoice_df["WorkMethodsFrequencyCross-Validation"].
                               isnull()==False)][
                                   ["Country", "CompensationAmount",
                                    "CompensationCurrency",
                                    "WorkMethodsFrequencyCross-Validation"]]

salary_df["CompensationAmount"] = pd.to_numeric(salary_df["CompensationAmount"],
                                                errors="coerce")

salary_df = salary_df.apply(lambda row: convert_salary(row, conversion_df), axis=1)
salary_df = salary_df[(salary_df["CompensationCurrency"] == "USD")]
salary_df = salary_df[salary_df["CompensationAmount"] < 100000]

# Continue with filtering X_1 and X_3:
salary_df = salary_df[(salary_df["Country"] == "France") &
                      (salary_df["WorkMethodsFrequencyCross-Validation"].
                       isin(["Often", "Most of the time"]))]
salary_df
# Out:
# Currency SPL is not in the list!
#       Country  CompensationAmount CompensationCurrency  \
# 1800   France           51420.518                  USD
# 1834   France           59791.300                  USD
# 2053   France           81316.168                  USD
# 2073   France           59791.300                  USD
# 2088   France           59791.300                  USD
# ...       ...                 ...                  ...
# 13420  France           51420.518                  USD
# 13592  France           41853.910                  USD
# 13984  France           59791.300                  USD
# 14014  France           71749.560                  USD
# 16502  France           65770.430                  USD
#
#       WorkMethodsFrequencyCross-Validation
# 1800                                 Often
# 1834                      Most of the time
# 2053                      Most of the time
# 2073                                 Often
# 2088                      Most of the time
# ...

# %%
# This cell focuses on the denominator of the probability function which is the
# number of data points which does not have missing value on columns 'Country',
# 'CompensationAmount', 'CompensationCurrency' and 'WorkMethodsFrequencyCross-Validation':
denominator_df = multipleChoice_df[(multipleChoice_df["Country"].isnull()
                                   ==False) & (multipleChoice_df["CompensationAmount"].
                                               isnull()==False) & (multipleChoice_df
                                                ["CompensationCurrency"].isnull()==False) &
                                                (multipleChoice_df
                                                 ["WorkMethodsFrequencyCross-Validation"].
                                                  isnull()==False)][
                                                      ["Country", "CompensationAmount",
                                                       "CompensationCurrency",
                                                       "WorkMethodsFrequencyCross-Validation"]]

# One edge case is that SPL does not exist in the conversion_df. Hence we should
# ignore it (A total of 1 case):
denominator_df = denominator_df[(denominator_df["CompensationCurrency"]=="SPL")==False]

denominator_df
# Out:
#               Country CompensationAmount CompensationCurrency  \
# 9              Russia            1200000                  RUB
# 14             Taiwan            1100000                  TWD
# 22      United States             100000                  USD
# 23     Czech Republic              20000                  CZK
# 25             Russia             624000                  RUB
# ...               ...                ...                  ...
# 16394           Japan            3500000                  JPY
# 16423           Other         12,000,000                  UGX
# 16502          France              55000                  EUR
# 16517         Germany              84000                  EUR
# 16525   United States             200000                  USD
#
#       WorkMethodsFrequencyCross-Validation
# 9                         Most of the time
# 14                                   Often
# 22                               Sometimes
# 23                               Sometimes
# ...

# %%
# This cell focuses on P(X_1 ∩ X_2 ∩ X_3):
print("P(X_1 ∩ X_2 ∩ X_3) =", len(salary_df)/len(denominator_df))
# Out:
# P(X_1 ∩ X_2 ∩ X_3) = 0.026395499783643445

# %% [markdown]
# # Question 7

# %% [markdown]
# What is the probability that a respondent uses C/C++ at work given that they are employed as a Programmer?
#
# Mathematical Notation of the Question: P(Y="C/C++" | X="Programmer")

# %%
# This cell focuses on X="Programmer":
prog_df = multipleChoice_df[(multipleChoice_df["CurrentJobTitleSelect"]=="Programmer") &
                            (multipleChoice_df["WorkToolsSelect"].isnull()==False)][
                                ["CurrentJobTitleSelect", "WorkToolsSelect"]]
prog_df
# Out:
#       CurrentJobTitleSelect                                    WorkToolsSelect
# 135              Programmer          Jupyter notebooks,Python,R,SQL,TensorFlow
# 166              Programmer  Cloudera,KNIME (free version),Python,R,Spark /...
# 255              Programmer  IBM Watson / Waton Analytics,Python,Spark / ML...
# 296              Programmer  IBM SPSS Modeler,IBM SPSS Statistics,Java,Micr...
# 521              Programmer  Hadoop/Hive/Pig,Java,NoSQL,R,RapidMiner (free ...
# ...                     ...                                                ...
# 16394            Programmer                                 Python,SQL,Tableau
# 16473            Programmer                                Amazon Web services
# 16677            Programmer  C/C++,Python,Spark / MLlib,TensorFlow,Unix she...
# 16689            Programmer  Amazon Web services,Cloudera,Python,Spark / ML...
# 16712            Programmer                                             Python
#
# [190 rows x 2 columns]

# %%
# This cell focuses on Y="C/C++" | X="Programmer":
c_cpp_df = prog_df[prog_df["WorkToolsSelect"].str.contains("C/C++", na=False,
                                                           regex=False)]
c_cpp_df
# Out:
#       CurrentJobTitleSelect                                    WorkToolsSelect
# 1429             Programmer  Amazon Web services,C/C++,Java,SQL,Tableau,Uni...
# 1484             Programmer  Amazon Web services,C/C++,Java,MATLAB/Octave,N...
# 1869             Programmer                                     C/C++,Python,R
# 1991             Programmer  C/C++,Java,NoSQL,Python,SQL,Tableau,Unix shell...
# 2872             Programmer                              C/C++,Java,Python,SQL
# 3194             Programmer                                 C/C++,NoSQL,Python
# 3755             Programmer  C/C++,Java,Jupyter notebooks,Python,SQL,Tensor...
# 3788             Programmer  Amazon Web services,C/C++,Cloudera,Google Clou...
# 3822             Programmer  C/C++,Jupyter notebooks,Microsoft Azure Machin...
# 4298             Programmer                                     C/C++,Python,R
# 4598             Programmer  C/C++,Java,MATLAB/Octave,Microsoft Excel Data ...
# ...

# %%
# This cell focuses on P(Y="C/C++" | X="Programmer"):
print("P(Y='C/C++' | X='Programmer') =", len(c_cpp_df)/len(prog_df))
# Out:
# P(Y='C/C++' | X='Programmer') = 0.17894736842105263

# %% [markdown]
# # Question 8

# %% [markdown]
# Question: Given the probability of a respondent wearing glasses is 0.15, and the probability of a respondent wearing glasses given they have a PhD is 0.25, find the probability of a respondent having a PhD given that they wear glasses.
#
# Mathematical Notation of the Question: P(X_1 | X_2) = P(X_2 | X_1) * P(X_1) / P(X_2) where X_1 is "respondent having a PhD" and X_2 is "respondent wears glasses".
#
# What is given? P(X_2) = 0.15 and P(X_2 | X_1) = 0.25.
#
# What is needed? P(X_1).

# %%
# This cell focuses on X_1:
glasses_df = multipleChoice_df[multipleChoice_df["FormalEducation"]==
                               "Doctoral degree"]["FormalEducation"]
glasses_df
# Out:
# 4        Doctoral degree
# 5        Doctoral degree
# 12       Doctoral degree
# 22       Doctoral degree
# 32       Doctoral degree
#               ...
# 16644    Doctoral degree
# 16646    Doctoral degree
# 16658    Doctoral degree
# 16660    Doctoral degree
# 16678    Doctoral degree
# Name: FormalEducation, Length: 2347, dtype: object

# %%
# This cell focuses on the denominator of the probability function which is the
# number of data points which does not have missing value on column
# 'FormalEducation':
denominator_df = multipleChoice_df[multipleChoice_df["FormalEducation"].isnull()
                                   ==False]["FormalEducation"]
denominator_df
# Out:
# 0                                        Bachelor's degree
# 1                                          Master's degree
# 2                                          Master's degree
# 3                                          Master's degree
# 4                                          Doctoral degree
#                                ...
# 16710                                    Bachelor's degree
# 16711                                      Master's degree
# 16712                                    Bachelor's degree
# 16714                               I prefer not to answer
# 16715    I did not complete any formal education past h...
# Name: FormalEducation, Length: 15015, dtype: object

# %%
# This cell focuses on P(X_1 | X_2) = P(X_2 | X_1) * P(X_1) / P(X_2):
P_X_1 = len(glasses_df)/len(denominator_df)
print("P(X_1) =", P_X_1)
print("P(X_1 | X_2) = P(X_2 | X_1) * P(X_1) / P(X_2) =", 0.25 * P_X_1 / 0.15)
# Out:
# P(X_1) = 0.1563103563103563
# P(X_1 | X_2) = P(X_2 | X_1) * P(X_1) / P(X_2) = 0.26051726051726054
